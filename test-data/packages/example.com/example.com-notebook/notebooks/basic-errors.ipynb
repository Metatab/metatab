# %%
#2017-09-11 17:09:40.560077
# %load_ext metapack.jupyter.magic

# %%
import pandas as pd
import numpy as np
import random

# %%
N = 2500

dfa = pd.DataFrame({
        'int1': range(0,N),
        'float2': np.linspace(0,1,N),
        'str3': np.random.choice( list('abcdefghij'), N) 
        
    })

# %%
dfb = dfa.copy()*2

# %%
# %mt_materialize dfa
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-5-ad39cfb33b03> in <module>()
# ----> 1 get_ipython().magic('mt_materialize dfa /var/folders/_8/4x14kzy53_9fxgt_b42thm200000gn/T/tmpmuabl3hc')
#
# /Volumes/Storage/proj/virt/metapack/lib/python3.6/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2144         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2145         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2146         return self.run_line_magic(magic_name, magic_arg_s)
#    2147
#    2148     #-------------------------------------------------------------------------
#
# /Volumes/Storage/proj/virt/metapack/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2065                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2066             with self.builtin_trap:
# -> 2067                 result = fn(*args,**kwargs)
#    2068             return result
#    2069
#
# <decorator-gen-132> in mt_materialize(self, line)
#
# /Volumes/Storage/proj/virt/metapack/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /Volumes/Storage/proj/virt-proj/metapack/metapack/metapack/jupyter/magic.py in mt_materialize(self, line)
#     277             df = self.shell.user_ns[args.df_name].fillna('')
#     278             gen = PandasDataframeSource(parse_app_url(path), df, cache=cache)
# --> 279             with open(path, 'w') as f:
#     280                 w = csv.writer(f)
#     281                 w.writerows(gen)
#
# NotADirectoryError: [Errno 20] Not a directory: '/var/folders/_8/4x14kzy53_9fxgt_b42thm200000gn/T/tmpmuabl3hc/dfa.csv'

# %%
# %mt_materialize_all /var/folders/_8/4x14kzy53_9fxgt_b42thm200000gn/T/tmpmuabl3hc

# %%
# %mt_show_metatab

# %%
# %mt_show_libdirs
