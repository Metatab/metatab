# %%
import metatab as mt
import pandas as pd
import numpy as np

doc = mt.open_package('http://s3.amazonaws.com/library.metatab.org/cdss.ca.gov-residential_care_facilities-2017-ca-6.csv')
doc
# Out:
# <h1>California Residential Elder Care Facilities</h1>
# <p>cdss.ca.gov-residential_care_facilities-2017-ca-6</p>
# <p>A list of licensed Residential Elder Care Facilities (RCFEs) from the California Department of Social Services.</p>
# <h2>Documentation</h2>
#
# <p><strong><a href="https://secure.dss.ca.gov/CareFacilitySearch/Home/selecttype" target="_blank" >CA DSS Care Facilities Home Page</a> </strong>This page has links to search forms and the data download page</p>
# <p><strong><a href="https://secure.dss.ca.gov/CareFacilitySearch/Home/DownloadData" target="_blank" >CA DSS Page with Link to Dataset</a> </strong>The link is not direct -- it links through Jaascript -- so the data is downloaded into this package.</p>
# <p><strong>Includedocumentation: </strong>docs/documentation.md</p>
# <h2>Contacts</h2>
#
# <p><strong>Origin: </strong> <a href="https://secure.dss.ca.gov/CareFacilitySearch/Home/DownloadData" target="_blank" >California Department of Social Services</a></p>
# ...

# %%
doc  = mt.open_package('http://s3.amazonaws.com/library.metatab.org/huduser.gov-zip_tract-2016-2.csv')
doc
# Out:
# <h1>ZIP-Tract Crosswalk</h1>
# <p>huduser.gov-zip_tract-2016-2</p>
# <p>Data files linking ZIP codes to 2010 Census tracts.</p>
# <h2>Documentation</h2>
#
# <p><strong><a href="https://www.huduser.gov/portal/datasets/usps_crosswalk.html" target="_blank" >Homepage</a> </strong>None</p>
# <p><strong><a href="file:docs/codebook.html" >Codebook</a> </strong>None</p>
# <p><strong>Note: </strong>None</p>
# <h2>Contacts</h2>
#
# <p><strong>Origin: </strong> <a href="https://www.huduser.gov" target="_blank" >U.S. Department of Housing and Urban Development</a></p>
# <p><strong>Creator: </strong><a href="mailto:Robert.N.Renner@hud.gov" target="_blank" >Robert Renner</a> <a href="https://www.huduser.gov" target="_blank" >U.S. Department of Housing and Urban Development</a></p>
# <p><strong>Wrangler: </strong><a href="mailto:eric@civicknowledge.com" target="_blank" >Eric Busboom</a> <a href="http://civicknowledge.com" target="_blank" >Civic Knowledge</a></p>
# <h2>Resources</h2>
# <ol>
# ...

# %%
r = doc.resource('zip-tract')
r
# Out:
# <Term: huduser.gov-zip_tract-2016-2.csv 21:1 root.datafile http://s3.amazonaws.com/library.metatab.org/huduser.gov-zip_tract-2016-2/data/zip-tract.csv ['zip-tract', 'ZIP to Tract crosswalk', '']>

# %%
r.dataframe()
# Out:
#           zip        tract  res_ratio  bus_ratio  oth_ratio  tot_ratio
# 0         501  36103158607   0.000000   1.000000   0.000000   1.000000
# 1         601  72001956600   0.136735   0.358911   0.347222   0.154270
# 2         601  72001956700   0.859996   0.636139   0.652778   0.842387
# 3         601  72001956300   0.003269   0.004950   0.000000   0.003343
# 4         602  72003430300   0.037744   0.272500   0.315789   0.055036
# 5         602  72003430200   0.961899   0.727500   0.684211   0.944633
# 6         602  72003430100   0.000357   0.000000   0.000000   0.000331
# 7         603  72005400502   0.016802   0.001903   0.011650   0.015841
# 8         603  72005400800   0.031375   0.081827   0.000000   0.033309
# 9         603  72005401000   0.076409   0.341579   0.153398   0.093107
# 10        603  72005400400   0.009773   0.002854   0.000000   0.009127
# 11        603  72005400600   0.509087   0.192198   0.572816   0.493338
# ...
