# %%
#2017-09-11 19:51:31.589962
# %load_ext metapack.jupyter.magic

# %%
import pandas as pd
import numpy as np
import random

# %%
N = 2500

dfa = pd.DataFrame({
        'int1': range(0,N),
        'float2': np.linspace(0,1,N),
        'str3': np.random.choice( list('abcdefghij'), N) 
        
    })

# %%
dfb = dfa.copy()*2

# %%
# %mt_materialize dfb /var/folders/_8/4x14kzy53_9fxgt_b42thm200000gn/T/tmpv8kk1fms
# Out:
# {
#     "df_name": "dfb",
#     "path": "/var/folders/_8/4x14kzy53_9fxgt_b42thm200000gn/T/tmpv8kk1fms/dfb.csv"
# }

# %%
# %mt_materialize_all /var/folders/_8/4x14kzy53_9fxgt_b42thm200000gn/T/tmpv8kk1fms
# Out:
# []

# %%
# %mt_show_metatab

# %%
# %mt_show_libdirs
# Out:
# []
